# %% [markdown]
# # Generating V3.2.0 Dataset

# %% [markdown]
# # Initial Setup

# %% [markdown]
# ## Jupyter Extensions

# %% [markdown]
# Load [watermark](https://github.com/rasbt/watermark) to see the state of the machine and environment that's running the notebook. To make sense of the options, take a look at the [usage](https://github.com/rasbt/watermark#usage) section of the readme.

# %%
# Load `watermark` extension
# %load_ext watermark
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark

# %%
# Display the status of the machine and other non-code related info
# %watermark -m -g -b -h
# Out:
# Compiler    : GCC 13.3.0
# OS          : Linux
# Release     : 6.14.0-23-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 22
# Architecture: 64bit
#
# Hostname: thousand-sunny-kbnt
#
# Git hash: 6781c5cca978abde6ea9e1aab796785f94ef2b13
#
# Git branch: main

# %% [markdown]
# Load [autoreload](https://ipython.org/ipython-doc/3/config/extensions/autoreload.html) which will always reload modules marked with `%aimport`.
#
# This behavior can be inverted by running `autoreload 2` which will set everything to be auto-reloaded *except* for modules marked with `%aimport`.

# %%
# Load `autoreload` extension
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Set autoreload behavior
# %autoreload 1

# %% [markdown]
# Load `matplotlib` in one of the more `jupyter`-friendly [rich-output modes](https://ipython.readthedocs.io/en/stable/interactive/plotting.html). Some options (that may or may not have worked) are `inline`, `notebook`, and `gtk`.

# %%
# Set the matplotlib mode
# %matplotlib inline

# %% [markdown]
# ## Imports

# %%
# Standard library imports
import pickle
from pathlib import Path
from datetime import datetime

# Third party
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %aimport hmdcpd.visualization
# %aimport hmdcpd.analysis
from hmdcpd import (
    visualization,
    analysis,
)

# %aimport bouncing_ball_task.bouncing_ball
# %aimport bouncing_ball_task.human_bouncing_ball.dataset
# %aimport bouncing_ball_task.human_bouncing_ball.catch
# %aimport bouncing_ball_task.human_bouncing_ball.straight
# %aimport bouncing_ball_task.human_bouncing_ball.bounce
# %aimport bouncing_ball_task.human_bouncing_ball.nonwall
# %aimport bouncing_ball_task.human_bouncing_ball.defaults
# %aimport bouncing_ball_task.utils.pyutils
# %aimport bouncing_ball_task.utils.taskutils
# %aimport bouncing_ball_task.utils.visualize
# %aimport bouncing_ball_task.utils.gif
from bouncing_ball_task.utils import pyutils, visualize, htaskutils
from bouncing_ball_task import index
import bouncing_ball_task.human_bouncing_ball.dataset as hbb
from bouncing_ball_task.human_bouncing_ball import defaults

# Display  versions of everything
# %watermark -v -iv
# Out:
# Python implementation: CPython
# Python version       : 3.13.5
# IPython version      : 9.3.0
#
# pandas            : 2.3.0
# seaborn           : 0.13.2
# numpy             : 2.3.0
# torch             : 2.6.0
# bouncing_ball_task: 0.0.0
# matplotlib        : 3.10.3

# %%
# Figures
default_fig_size = (10, 5)
default_fig_size_smaller = (8, 5)
default_font_label = 14
default_font_title = 18
default_aspect = default_fig_size[0] / default_fig_size[1]
default_height = default_fig_size[1]
dpi = 200

# Experiment defaults
default_valid_colors={1: "red", 2: "green", 3: "blue"}

# Color Prediction Plots
color_predition_name_column_dict = {
    "Color Entered": "color_entered",
    "Next Color": "color_next",
    "Third Color": "color_after_next",
}

# %% [markdown]
# # Definitions

# %% [markdown]
# ## Plotting Functions

# %%
## Maximum Task Sensitivity

def compute_slope_and_residuals(group, cwc):
    """Compute slope and residual variance using least squares regression."""
    X = np.vstack([group, np.ones_like(group)]).T  # Design matrix
    slope, intercept = np.linalg.lstsq(X, cwc, rcond=None)[
        0
    ]  # Solve for slope and intercept

    residuals = cwc - (slope * group + intercept)
    residual_var = residuals.var(
        ddof=1
    )  # Use variance inddstead of std to avoid redundant sqrt
    return slope, residual_var


def compute_within_subject_hz_effect_size(
    idx_time,
    cwc,
    index_high,
    index_low,
):
    """Compute within-subject standardized effect size for a single participant."""
    # Compute statistics for high and low conditions
    slope_high, residual_var_high = compute_slope_and_residuals(
        idx_time[index_high], cwc[index_high]
    )
    slope_low, residual_var_low = compute_slope_and_residuals(
        idx_time[index_low], cwc[index_low]
    )
    # Compute slope difference
    slope_diff = slope_high - slope_low

    # Compute pooled standard deviation (avoid redundant sqrt)
    sigma_pooled = np.sqrt((residual_var_high + residual_var_low) / 2)

    # Compute within-subject effect size (Cohen’s d)
    d_within = (
        slope_diff / sigma_pooled if sigma_pooled > 0 else np.nan
    )  # Avoid division by zero

    return {
        "slope_high": slope_high,
        "slope_low": slope_low,
        "slope_diff": slope_diff,
        "residual_var_high": residual_var_high,
        "residual_var_low": residual_var_low,
        "sigma_pooled": sigma_pooled,
        "d_within": d_within,
    }


def compute_within_subject_cont_effect_size(
    pccovc,
    cwc,
    index_bounce,
):
    """Compute within-subject standardized effect size for a single participant."""
    # Compute statistics for high and low conditions
    slope, residual_var = compute_slope_and_residuals(
        pccovc,
        cwc[index_bounce],
    )

    # Compute standardized effect size (Cohen’s d)
    sigma = np.sqrt(residual_var)
    d_within = (
        slope / sigma if sigma > 0 else np.nan
    )  # Avoid division by zero

    return {
        "slope": slope,
        "residual_var": residual_var,
        "d_within": d_within,
    }

def plot_effective_stats(df_data):
    # Create the subplots
    palette = visualization.get_color_palette(
        ["Low", "High"],
        (("Blues", 1), ("Reds", 1)),
        linspace_range=(0.75, 1),
    )
    palette_trial = visualization.get_color_palette(
        ["Catch", "Straight", "Nonwall", "Bounce"],
        (("Greens", 1), ("Blues", 1), ("Wistia", 1), ("Reds", 1)),
        linspace_range=(0.75, 1),
    )
    palette_contingency = visualization.get_color_palette(
        ["Low", "Medium", "High"],
        (("Blues", 1), ("Wistia", 1), ("Reds", 1)),
        linspace_range=(0.75, 1),
    )

    plot_params = [
        [
            (
                "PCCNVC_effective",
                "Observed Hazard Rates",
                "Effective Hazard Rate Bins",
                {
                    "hue": "Hazard Rate",
                    "legend": True,
                    "palette": palette,
                    "multiple": "stack",
                }
            ),
            (
                "PCCOVC_effective",
                "Observed Trial Contingency",
                "Effective Contingency Bins",
                {
                    "hue": "Contingency",
                    "palette": palette_contingency,
                    "legend": True,
                    "multiple": "stack",
                },
            ),
            (
                "PVC_effective",
                "Observed Trial Random Bounce",
                "Effective Random Bounce Bins",
                {
                    "hue": "trial",
                    "palette": palette_trial,
                    "legend": True,
                    "multiple": "stack",
                },
            ),
            (
                "length",
                "Distribution of Video Lengths",
                "Video Length Bins",
                {
                    "hue": "trial",
                    "legend": True,
                    "palette": palette_trial,
                    "multiple": "stack",
                }
            ),
        ],
        [
            (
                "Color Change Random",
                "Number of Random Color Changes",
                "Random Color Change Bins",
                {
                    "hue": "Hazard Rate",
                    "legend": False,
                    "discrete": True,
                    "palette": palette,
                    "multiple": "stack",
                }
            ),
            (
                "Color Change Bounce",
                "Number of Bounce Color Changes",
                "Bounce Color Changes",
                {
                    "discrete": True,
                    "hue": "Contingency",
                    "palette": palette_contingency,
                    "legend": False,
                    "multiple": "stack",
                }
            ),
            (
                "Random Bounces",
                "Number of Random Bounces",
                "Number of Random Bounces",
                {
                    "discrete": True,
                    "hue": "trial",
                    "palette": palette_trial,
                    "legend": False,
                    "multiple": "stack",
                }
            ),
            (
                "Bounces",
                "Number of Wall Bounces",
                "Number of Wall Bounces",
                {
                    "discrete": True,
                    "hue": "trial",
                    "palette": palette_trial,
                    "legend": True,
                    "multiple": "stack",
                }
            ),
        ],
    ]

    rows = 2
    fig, axes = plt.subplots(
        rows,
        len(plot_params[0]),
        figsize=(len(plot_params[0])*4, rows*4),
    )

    for i, row_plots in enumerate(plot_params):
        for j, (col, title, xlabel, plot_dict) in enumerate(row_plots):
            ax = axes[i, j]
            sns.histplot(
                df_data,
                x=col,
                ax=ax,
                **plot_dict,
            )
            ax.set_title(title)
            ax.set_xlabel(xlabel)
            if j != 0:
                ax.set_ylabel(None)

    plt.suptitle(f"Task Statstics for {len(df_data)} Videos")
    plt.tight_layout()

# %% [markdown]
# ## Pipeline Function

# %%
def generate_dataset(
    human_dataset_parameters,
    task_parameters,
    seed=None,
):
    # Seed
    seed = pyutils.set_global_seed(seed)
    task_parameters["seed"] = human_dataset_parameters["seed"] = seed
    print(f"Dataset Seed: {seed}")

    task, samples, targets, df_data, dict_metadata = hbb.generate_video_dataset(
        human_dataset_parameters,
        task_parameters,
        hbb.dict_trial_type_generation_funcs,
        shuffle=False,
    )

    dict_metadata["name"] = name_dataset = htaskutils.generate_dataset_name(
        defaults.name_dataset,
        seed=dict_metadata["seed"],
    )
    print(f"Dataset name: {name_dataset}")

    if not (variable_length := human_dataset_parameters["variable_length"]):
        try:
            samples = torch.from_numpy(samples)
            targets = torch.from_numpy(targets)
        except TypeError:
            pass
        batch_size, timesteps, _ = samples.shape

    else:
        try:
            samples = [torch.from_numpy(sample) for sample in samples]
            targets = [torch.from_numpy(target) for target in targets]
        except TypeError:
            pass

        batch_size = len(samples)
        timesteps = torch.from_numpy(df_data.length.values)

    task_parameters["batch_size"] = batch_size
    dict_metadata["task_parameters"] = task_parameters
    dict_metadata["human_dataset_parameters"] = human_dataset_parameters

    pccnvc_effective = torch.from_numpy(df_data.PCCNVC_effective.to_numpy())
    pccovc_effective = torch.from_numpy(df_data.PCCOVC_effective.to_numpy())
    pvc_effective = torch.from_numpy(df_data.PVC_effective.to_numpy())
    correct_response = torch.from_numpy(df_data.correct_response.to_numpy()) - 1
    color_entered = torch.from_numpy(df_data.color_entered.to_numpy()) - 1
    color_after_next = torch.from_numpy(df_data.color_after_next.to_numpy()) - 1
    color_entered_rgb = torch.eye(3)[color_entered]

    last_visible_idx = torch.from_numpy(df_data.last_visible_color_idx.values)
    timesteps_to_end = torch.from_numpy(df_data.length.values) - last_visible_idx

    if not variable_length:
        timesteps_idx = torch.arange(timesteps).repeat((batch_size, 1))
        mask_last_timesteps = timesteps_idx > last_visible_idx.unsqueeze(-1)
        bounce_last_timesteps = (mask_last_timesteps & targets[:, :, 5:7].any(dim=-1)).any(dim=-1)
    else:
        timesteps_idx = [torch.arange(t) for t in timesteps]
        mask_last_timesteps = [timesteps_idx[i] > last_visible_idx[i] for i in range(batch_size)]
        bounce_last_timesteps = torch.stack([
            (mask & target[:, 5:7].any(dim=-1)).any(dim=-1)
            for mask, target in zip(mask_last_timesteps, targets)
        ])

    # Subtract a timestep for the bounce since random changes cannot happen
    timesteps_random_change = timesteps_to_end - bounce_last_timesteps.int()

    # Transition matrix for random changes
    third = torch.zeros_like(pccnvc_effective)
    T_ccr = torch.stack(
        [
            torch.stack([1 - pccnvc_effective, pccnvc_effective, third], dim=-1),
            torch.stack([third, 1 - pccnvc_effective, pccnvc_effective], dim=-1),
            torch.stack([pccnvc_effective, third, 1 - pccnvc_effective], dim=-1),
        ],
        dim=1,
    )

    max_exponent = int(timesteps_random_change.max().item())

    # Precompute all powers from 0 to max_exponent.
    # For k = 0, use the identity matrix.
    I = torch.eye(T_ccr.shape[-1])
    T_ccr_powers = []
    for k in range(max_exponent + 1):
        if k == 0:
            # Expand identity to shape [B, 3, 3]
            T_ccr_powers.append(I.unsqueeze(0).expand(batch_size, -1, -1))
        else:
            T_ccr_powers.append(torch.matrix_power(T_ccr, k))
    # Stack into a tensor of shape [max_exponent+1, B, 3, 3]
    T_ccr_powers = torch.stack(T_ccr_powers, dim=0)
    T_ccr_exp = T_ccr_powers[timesteps_random_change, torch.arange(batch_size), :, :].float()

    # Apply random color transitions
    belief_oracle = torch.bmm(color_entered_rgb.unsqueeze(1), T_ccr_exp).squeeze(1)

    # Transition for bounces
    T_ccb = torch.stack(
        [
            torch.stack([1 - pccovc_effective, pccovc_effective, third], dim=-1),
            torch.stack([third, 1 - pccovc_effective, pccovc_effective], dim=-1),
            torch.stack([pccovc_effective, third, 1 - pccovc_effective], dim=-1),
        ],
        dim=1,
    ).float()
    belief_oracle[bounce_last_timesteps] = torch.bmm(
        belief_oracle[bounce_last_timesteps].unsqueeze(1),
        T_ccb[bounce_last_timesteps],
    ).squeeze(1)

    labels_coded = torch.where(color_entered == correct_response, -1, 1)
    # labels_coded[labels_coded == 1] = torch.where(
    #     correct_response[labels_coded == 1] == color_after_next[labels_coded == 1],
    #     2,
    #     1,
    # )
    labels_prob = belief_oracle[torch.arange(batch_size), correct_response]
    labels_weighted = (labels_coded * labels_prob).numpy()
    df_data["cwl"] = labels_weighted

    df_straight = df_data[df_data["trial"] == "Straight"]
    df_bounce = df_data[df_data["trial"] == "Bounce"]
    df_nonwall = df_data[df_data["trial"] == "Nonwall"]
    df_bounce_comb = df_data[df_data["trial"].isin(["Bounce", "Nonwall"])]

    effect_hz_ico = compute_within_subject_hz_effect_size(
        df_data.idx_time.to_numpy(),
        labels_weighted,
        df_straight[df_straight["Hazard Rate"] == "High"].index,
        df_straight[df_straight["Hazard Rate"] == "Low"].index,
    )

    effect_cont_ico_bounce = compute_within_subject_cont_effect_size(
        df_bounce.PCCOVC.to_numpy(),
        labels_weighted,
        df_bounce.index,
    )

    effect_cont_ico_nonwall = compute_within_subject_cont_effect_size(
        df_nonwall.PCCOVC.to_numpy(),
        labels_weighted,
        df_nonwall.index,
    )

    effect_cont_ico = compute_within_subject_cont_effect_size(
        df_bounce_comb.PCCOVC.to_numpy(),
        labels_weighted,
        df_bounce_comb.index,
    )
    print(f"\nLabels Straight - Hz Slope Diff: {effect_hz_ico['slope_diff']:.3f}")
    print(f"  Labels Straight - High Hz Slope: {effect_hz_ico['slope_high']:.3f}")
    print(f"  Labels Straight - Low Hz Slope: {effect_hz_ico['slope_low']:.3f}")
    print(f"\nLabels Bounce + Nonwall - Cont Slope: {effect_cont_ico['slope']:.3f}")
    print(f"  Labels Bounce - Cont Slope: {effect_cont_ico_bounce['slope']:.3f}")
    print(f"  Labels Nonwall - Cont Slope: {effect_cont_ico_nonwall['slope']:.3f}")

    percent_no_change = (color_entered == correct_response).float().mean() * 100
    print(f"\nChange Split")
    print(f"  No Change: {percent_no_change:.1f}%")
    print(f"  Change: {100 - percent_no_change:.1f}%")

    print(f"\nTotal Wall Bounces: {df_data.Bounces.sum()}")
    print(f"Total Random Bounces: {df_data['Random Bounces'].sum()}")

    dict_hz = {}
    for hz, df_hz in df_straight.groupby("Hazard Rate"):
        dict_hz[hz] = {}
        for pos, df_pos in df_hz.groupby("idx_time"):
            dict_hz[hz][pos] = (df_pos.color_entered == df_pos.correct_response).mean()

    print(f"Low HZ -- {dict_hz['Low'][0]:.2f} -- {dict_hz['Low'][1]:.2f} -- {dict_hz['Low'][2]:.2f}")
    print(f"High HZ -- {dict_hz['High'][0]:.2f} -- {dict_hz['High'][1]:.2f} -- {dict_hz['High'][2]:.2f}")

    plot_effective_stats(df_data)
    ylim = (-1, 1.0)

    visualization.multi_plot_color_prediction_counts(
        df_straight,
        "Label Hazard Rate Sensitivity",
        hue="Hazard Rate",
        x="idx_time",
        y="cwl",
        ylabel="Confidence Weighted Choice",
        xlabel="Grayzone Position",
        ylim=ylim,
        palette_labels=["Low", "High"],
        palette_color_counts=(("Greens", 2),),
        palette_linspace_range=(0.333, 1.2),
    )

    visualization.multi_plot_color_prediction_counts(
        df_bounce_comb,
        "Label Contingency Sensitivity - Bounce + Nonwall Trials",
        hue="Contingency",
        x="Contingency",
        y="cwl",
        ylabel="Confidence Weighted Choice",
        ylim=ylim,
        palette_labels=['Low', 'Medium', 'High'],
        palette_color_counts=(("Reds", 3),),
        palette_linspace_range=(0.333, 1.2),
        plot_2=None,
        no_legend=True,
    )

    visualization.multi_plot_color_prediction_counts(
        df_bounce,
        "Label Contingency Sensitivity - Bounce Trials",
        hue="Contingency",
        x="Contingency",
        y="cwl",
        ylabel="Confidence Weighted Choice",
        ylim=ylim,
        palette_labels=['Low', 'Medium', 'High'],
        palette_color_counts=(("Reds", 3),),
        palette_linspace_range=(0.333, 1.2),
        plot_2=None,
        no_legend=True,
    )

    visualization.multi_plot_color_prediction_counts(
        df_nonwall,
        "Label Contingency Sensitivity - Nonwall Bounce Trials",
        hue="Contingency",
        x="Contingency",
        y="cwl",
        ylabel="Confidence Weighted Choice",
        ylim=ylim,
        palette_labels=['Low', 'Medium', 'High'],
        palette_color_counts=(("Reds", 3),),
        palette_linspace_range=(0.333, 1.2),
        plot_2=None,
        no_legend=True,
    )

    return task, samples, targets, df_data, dict_metadata

# %% [markdown]
# # Generating the Dataset
#
# Potential Seeds:
# - 2714814165
# - 202492180
# - 4013080081

# %%
task_parameters = defaults.task_parameters.asdict
human_dataset_parameters = defaults.human_dataset_parameters.asdict
seed = None

human_dataset_parameters["velocity_lower"] = 0.1
human_dataset_parameters["velocity_upper"] = 0.12
human_dataset_parameters["pvc"] = 0.0

# human_dataset_parameters["velocity_lower"] = 0.08
# human_dataset_parameters["velocity_upper"] = 2/15

human_dataset_parameters["pccnvc_lower"] = 0.00975
human_dataset_parameters["pccnvc_upper"] = 0.095
human_dataset_parameters["pccovc_lower"] = 0.1
human_dataset_parameters["pccovc_upper"] = 0.9
human_dataset_parameters["video_length_min_s"] = 7.5
human_dataset_parameters["transition_tol"] = 1
human_dataset_parameters["num_blocks"] = 10

human_dataset_parameters["border_tolerance_inner"] = 0.1
# human_dataset_parameters["total_dataset_length"] = 350
human_dataset_parameters["duration"] = 50
human_dataset_parameters["exp_scale"] = 5

human_dataset_parameters["trial_type_split"] =  (0.05, -1, -1, 0)
# human_dataset_parameters["min_t_color_change_after_bounce"] = 45
# human_dataset_parameters["min_t_color_change_after_random"] = 500
# human_dataset_parameters["min_t_velocity_change_after_bounce"] = 75
# human_dataset_parameters["min_t_velocity_change_after_random"] = 160

task_parameters["warmup_t_no_rand_velocity_change"] = 30
task_parameters["warmup_t_no_rand_color_change"] = 2

task_parameters["min_t_color_change_after_bounce"] = 15
task_parameters["min_t_color_change_after_random"] = 15
task_parameters["min_t_velocity_change_after_bounce"] = 30
task_parameters["min_t_velocity_change_after_random"] = 15

# print(human_dataset_parameters["warmup_t_no_rand_velocity_change"])

task, samples, targets, df_data, dict_metadata = generate_dataset(
    human_dataset_parameters,
    task_parameters,
    seed,
)
seed = task_parameters["seed"]
# Out:
# 2025-07-07 17:16:47.620 | DEBUG    | bouncing_ball_task.bouncing_ball:color_mask_mode:511 - Running color_mask_mode setter
# 2025-07-07 17:16:47.621 | DEBUG    | bouncing_ball_task.bouncing_ball:transitioning_change_mode:489 - Running transitioning_change_mode setter
# 2025-07-07 17:16:47.621 | DEBUG    | bouncing_ball_task.bouncing_ball:sequence_mode:441 - Running sequence_mode setter
# 2025-07-07 17:16:47.622 | DEBUG    | bouncing_ball_task.bouncing_ball:resample_change_probabilities:537 - Running resample_change_probabilities
# 2025-07-07 17:16:47.622 | DEBUG    | bouncing_ball_task.bouncing_ball:color_sampling:418 - Running color_sampling setter
# 2025-07-07 17:16:47.623 | DEBUG    | bouncing_ball_task.bouncing_ball:return_change_mode:475 - Running return_change_mode setter
# 2025-07-07 17:16:47.641 | DEBUG    | bouncing_ball_task.bouncing_ball:color_mask_mode:511 - Running color_mask_mode setter
# 2025-07-07 17:16:47.642 | DEBUG    | bouncing_ball_task.bouncing_ball:transitioning_change_mode:489 - Running transitioning_change_mode setter
# 2025-07-07 17:16:47.642 | DEBUG    | bouncing_ball_task.bouncing_ball:sequence_mode:441 - Running sequence_mode setter
# 2025-07-07 17:16:47.643 | DEBUG    | bouncing_ball_task.bouncing_ball:resample_change_probabilities:537 - Running resample_change_probabilities
# 2025-07-07 17:16:47.643 | DEBUG    | bouncing_ball_task.bouncing_ball:color_sampling:418 - Running color_sampling setter
# 2025-07-07 17:16:47.644 | DEBUG    | bouncing_ball_task.bouncing_ball:return_change_mode:475 - Running return_change_mode setter
# 2025-07-07 17:16:47.667 | DEBUG    | bouncing_ball_task.bouncing_ball:color_mask_mode:511 - Running color_mask_mode setter
# 2025-07-07 17:16:47.668 | DEBUG    | bouncing_ball_task.bouncing_ball:transitioning_change_mode:489 - Running transitioning_change_mode setter
# 2025-07-07 17:16:47.668 | DEBUG    | bouncing_ball_task.bouncing_ball:sequence_mode:441 - Running sequence_mode setter
# 2025-07-07 17:16:47.668 | DEBUG    | bouncing_ball_task.bouncing_ball:resample_change_probabilities:537 - Running resample_change_probabilities
# 2025-07-07 17:16:47.668 | DEBUG    | bouncing_ball_task.bouncing_ball:color_sampling:418 - Running color_sampling setter
# 2025-07-07 17:16:47.669 | DEBUG    | bouncing_ball_task.bouncing_ball:return_change_mode:475 - Running return_change_mode setter
# 2025-07-07 17:16:47.692 | DEBUG    | bouncing_ball_task.bouncing_ball:color_mask_mode:511 - Running color_mask_mode setter
# 2025-07-07 17:16:47.693 | DEBUG    | bouncing_ball_task.bouncing_ball:transitioning_change_mode:489 - Running transitioning_change_mode setter
# 2025-07-07 17:16:47.693 | DEBUG    | bouncing_ball_task.bouncing_ball:sequence_mode:441 - Running sequence_mode setter
# 2025-07-07 17:16:47.697 | DEBUG    | bouncing_ball_task.bouncing_ball:color_sampling:418 - Running color_sampling setter
# 2025-07-07 17:16:47.699 | DEBUG    | bouncing_ball_task.bouncing_ball:return_change_mode:475 - Running return_change_mode setter
# Dataset Seed: 4169234244
# Dataset Generation Summary
#   Num Total Trials: 154 (29 min 40.2 sec)
#     ball_radius:                         10
#     dt:                                  0.1
#     duration:                            50
#     exp_scale:                           5
#     border_tolerance_outer:              1.25
#     mask_center:                         0.5
#     mask_fraction:                       0.3333333333333333
#     size_x:                              256
#     size_y:                              256
#     num_pos_x_endpoints:                 3
#     num_pos_y_endpoints:                 8
#     y_pos_multiplier:                    8
#     pvc:                                 0.0
#     num_y_velocities:                    2
#     bounce_offset:                       0.4
#     border_tolerance_inner:              0.1
#     num_pos_x_linspace_bounce:           5
#     idx_linspace_bounce:                 0
#     bounce_timestep:                     5
#     repeat_factor:                       3
#     seed:                                4169234244
#     num_blocks:                          10
#     variable_length:                     True
#     standard:                            True
#     catch_ncc_nvc_timesteps:             20
#     transition_tol:                      1
#     length_trials_ms:                    1780200
#     video_length_max_f:                  441
#     video_length_max_ms:                 22050
#     video_length_min_f:                  150
#     video_length_min_ms:                 7500
#     final_velocity_x_magnitude:          28.16
#     final_velocity_y_magnitude_linspace: [25.6  30.72]
#     pccnvc_linspace:                     [0.00975 0.095  ]
#     pccovc_linspace:                     [0.1 0.5 0.9]
#     mask_size:                           85
#     mask_start:                          86
#     mask_end:                            170
#     x_grayzone_linspace:                 [ 97. 128. 159.]
#     x_grayzone_linspace_sides:           [[ 97. 128. 159.]
#  [159. 128.  97.]]
#     diff:                                31.0
#   Num Catch Trials: 11 (1 min 22.5 sec)
#     Min Video Length (s):  7.5
#     Max Video Length (s):  7.5
#     Color Splits:          (0.36, 0.36, 0.27)
#     pccnvc Splits:         (0.45, 0.55)
#     pccovc Splits:         (0.36, 0.36, 0.27)
#     Stat Comb Splits:      (0.18, 0.18, 0.09, 0.18, 0.18, 0.18)
#   Num Straight Trials: 71 (14 min 3.2 sec)
#     Min Video Length (s):  7.6
#     Max Video Length (s):  21.8
#     Color Splits:          (0.32, 0.34, 0.34)
#     pccnvc Splits:         (0.49, 0.51)
#     pccovc Splits:         (0.34, 0.34, 0.32)
#     Stat Comb Splits:      (0.17, 0.17, 0.15, 0.17, 0.17, 0.17)
#     End time Splits:       (0.34, 0.32, 0.34)
#     Left/Right Splits:     (0.49, 0.51)
#     Top/Bottom Splits:     (0.51, 0.49)
#     Velocity Splits:       (0.49, 0.51)
#   Num Bounce Trials: 72 (14 min 14.5 sec)
#     Min Video Length (s):  7.7
#     Max Video Length (s):  22.0
#     Color Splits:          (0.33, 0.33, 0.33)
#     pccnvc Splits:         (0.5, 0.5)
#     pccovc Splits:         (0.33, 0.33, 0.33)
#     Stat Comb Splits:      (0.17, 0.17, 0.17, 0.17, 0.17, 0.17)
#     End time Splits:       (1.0)
#     Left/Right Splits:     (0.5, 0.5)
#     Top/Bottom Splits:     (0.5, 0.5)
#     Velocity Splits:       (0.5, 0.5)
# Dataset name: hbb_dataset_250707_171647_4169234244
#
# Labels Straight - Hz Slope Diff: 0.454
#   Labels Straight - High Hz Slope: 0.557
#   Labels Straight - Low Hz Slope: 0.103
#
# Labels Bounce + Nonwall - Cont Slope: 1.363
#   Labels Bounce - Cont Slope: 1.363
#   Labels Nonwall - Cont Slope: 0.000
#
# Change Split
#   No Change: 59.1%
#   Change: 40.9%
#
# Total Wall Bounces: 852
# Total Random Bounces: 0
# Low HZ -- 1.00 -- 0.92 -- 0.89
# High HZ -- 1.00 -- 0.45 -- 0.13
# /home/apra/Work/Bouncing-Ball-Task/src/bouncing_ball_task/human_bouncing_ball/dataset.py:578: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for val, df_group in df_data.groupby(group):
# /home/apra/Work/Bouncing-Ball-Task/src/bouncing_ball_task/human_bouncing_ball/dataset.py:578: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for val, df_group in df_data.groupby(group):
# /tmp/ipykernel_18470/2463725689.py:11: RuntimeWarning: Degrees of freedom <= 0 for slice
#   residual_var = residuals.var(
# /home/apra/miniconda3/envs/hmdcpd/lib/python3.13/site-packages/numpy/_core/_methods.py:180: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/apra/miniconda3/envs/hmdcpd/lib/python3.13/site-packages/numpy/_core/_methods.py:214: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /tmp/ipykernel_18470/2280967312.py:171: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for hz, df_hz in df_straight.groupby("Hazard Rate"):

# %% [markdown]
# # Saving the Dataset

# %%
print(dict_metadata["name"])
dir_base = index.dir_repo / "data/hmdcpd"
dryrun = False

path_videos = hbb.save_video_dataset(
    dir_base,
    dict_metadata["name"],
    df_data,
    dict_metadata,
    samples,
    targets,
    task,
    duration=human_dataset_parameters["duration"],
    mode=defaults.mode,
    multiplier=2,
    save_target=True,
    save_animation=True,
    display_animation=defaults.display_animation,
    num_sequences=1,
    as_mp4=True,
    include_timestep=defaults.include_timestep,
    return_path=True,
    dryrun=dryrun,
)
# Out:
# 2025-07-07 17:17:54.265 | INFO     | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:633 - Saving dataset to /home/apra/Work/Bouncing-Ball-Task/data/hmdcpd/hbb_dataset_250707_171647_4169234244 (dir_dataset)
# 2025-07-07 17:17:54.265 | INFO     | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:641 - Saving trial metadata to to /dir_dataset/trial_meta
# 2025-07-07 17:17:54.268 | INFO     | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:650 - Saving dataset metadata to to /dir_dataset/dataset_meta
# 2025-07-07 17:17:54.270 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# hbb_dataset_250707_171647_4169234244
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:17:54.664 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:17:55.051 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:17:55.444 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:17:55.842 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:17:56.229 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:17:56.616 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:17:56.998 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:17:57.387 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:17:57.783 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:17:58.178 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:17:58.570 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:17:59.013 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:17:59.459 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:17:59.915 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:00.910 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:01.347 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:02.170 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:02.582 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:02.968 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:03.721 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:04.170 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:04.572 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:05.189 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:06.140 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:06.914 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:07.788 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:08.221 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:08.673 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:09.370 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:09.846 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:10.273 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:11.064 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:11.662 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:12.044 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:12.449 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:12.896 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:13.484 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:13.922 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:14.454 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:14.926 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:15.910 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:16.317 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:16.835 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:17.329 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:17.866 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:18.694 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:19.169 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:19.697 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:20.369 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:20.891 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:21.358 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:21.863 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:22.384 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:22.848 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:23.486 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:23.988 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:24.984 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:25.851 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:26.277 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:26.943 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:27.986 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:28.509 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:28.961 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:29.452 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:29.886 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:30.653 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:31.422 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:32.117 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:32.610 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:33.022 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:33.796 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:34.337 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:34.849 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:35.329 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:36.113 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:36.587 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:37.127 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:38.069 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:38.700 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:39.727 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:40.316 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:40.933 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:41.339 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:41.801 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:42.770 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:43.186 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:43.803 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:44.442 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:45.422 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:45.916 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:46.872 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:47.919 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:48.487 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:48.999 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:49.613 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:50.019 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:50.609 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:51.571 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:52.263 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:52.681 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:53.110 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:53.559 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:53.977 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:54.542 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:55.019 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:55.511 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:56.044 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:56.457 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:57.142 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:57.651 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:58.359 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:58.881 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:18:59.487 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:00.134 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:00.663 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:01.113 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:01.585 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:02.202 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:02.607 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:03.128 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:03.719 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:04.244 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:04.936 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:05.624 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:06.246 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:06.660 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:07.237 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:07.783 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:08.859 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:09.444 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:10.137 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:10.888 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:11.405 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:11.836 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:12.276 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:12.674 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:13.145 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:13.649 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:14.159 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:15.052 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:15.983 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:16.547 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:17.137 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:17.690 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:18.190 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:18.603 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:19.265 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:19.897 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:20.474 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:21.057 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:21.958 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:22.782 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
# 2025-07-07 17:19:23.194 | DEBUG    | bouncing_ball_task.human_bouncing_ball.dataset:save_video_dataset:692 - Generating video files in /dir_dataset/videos/{dir_block.stem}/{dir_video.stem}
# OpenCV: FFMPEG: tag 0x34363248/'H264' is not supported with codec id 27 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x31637661/'avc1'
